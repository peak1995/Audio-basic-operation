# %% [markdown]
# # Python 音频处理

# %% [markdown]
# * 音频相关的第三方包   通过pip 安装
# * wave  pyaudio soundfile sounddevice librosa
# * matplotlib numpy scipy

# %%
# %matplotlib inline

# %%
import soundfile as sf
import sounddevice as sd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from scipy import signal
import librosa

# %%
# from scipy.fftpack import fft,ifft
# from python_speech_features import mfcc,logfbank

# %%
[data,fs]=sf.read('weina.wav')

# %%
len(data)
# Out:
# 50047

# %%
print(fs)
# Out:
# 16000

# %%
# ?abs()

# %%
sd.play(data,fs)

# %%
z = np.linspace(1,len(data)/fs,len(data))

# %%
z
# Out:
# array([1.        , 1.00004252, 1.00008504, ..., 3.12785246, 3.12789498,
#        3.1279375 ])

# %%
# fname 为 你下载的字体库路径，注意 SimHei.ttf 字体的路径
zhfont1 = matplotlib.font_manager.FontProperties(fname="SimHei.ttf")
plt.plot(z,data)
plt.xlabel("Time(s)")
plt.ylabel("amplitude")
# plt.xticks(z)
plt.title("波形图") 
plt.rcParams['font.sans-serif']=['Simhei']     #解决中文显示问题，目前只知道黑体可行
plt.rcParams['axes.unicode_minus']=False

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/Users/peak/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# * 显示中文乱码解决 https://blog.csdn.net/zz_moon/article/details/80469753
# * https://blog.csdn.net/ccblogger/article/details/79613335
# * http://www.runoob.com/numpy/numpy-matplotlib.html

# %%
plt.specgram(data,Fs = fs, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency')
plt.xlabel('time(seconds)')
# Out:
# Text(0.5,0,'time(seconds)')

# %%
plt.specgram(data, NFFT=1024, Fs=fs, noverlap=500)
plt.show()

# %%
c=librosa.stft(data)

# %%
plt.plot(c)
plt.show
# Out:
# /Users/peak/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
a=np.array(fft(data))

# %%
plt.plot(a)
# Out:
# /Users/peak/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
c=round(len(a)/2)
dd=a[0:c]

# %%
plt.plot(dd)
# Out:
# /Users/peak/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
